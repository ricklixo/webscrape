# %%
import pandas as pd

# %%
df = pd.read_csv('InfoeInfo_articles.csv')

# %%
df
# Out:
#                                                titulo  \
# 0         A biblioteca do futuro: um olhar no passado
# 1   Dados governamentais abertos em aplicativos br...
# 2   Encontrabilidade da Informação em Repositórios...
# 3   Atuação dos profissionais da informação no Cic...
# 4   Cientificidade da Organização da Informação: u...
# 5   Um estudo das contribuições de Schopenhauer pa...
# 6               O aspecto icônico da linguagem visual
# 7   Política de indexação e seus sentidos: um estu...
# 8   Linguagens de indexação em bibliotecas univers...
# 9   O assunto “classificação” na literatura brasil...
# 10  Diagnóstico da produção intelectual da Pós-gra...
# 11  Atores do sistema de comunicação científica: a...
# 12  Knowledge creation and knowledge transfer: an ...
# 13  Avaliação da aplicação do método "análise de c...
# 14  Inteligencia Organizacional: aproximación teór...
# 15  Perfil e lugar dos arquivos privados instituci...
# ...
